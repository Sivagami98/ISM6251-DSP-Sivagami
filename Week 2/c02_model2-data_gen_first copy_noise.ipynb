# %% [markdown]
# # Predictive Modeling Example

# %% [markdown]
# ## Step 1: Import a number of libraries that we expect to use

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


np.random.seed(1) # set this to ensure the results are repeatable.

# %% [markdown]
# ## Step 2:  Define a hidden linear relationship/model
#
# First let's define our relationship (normally, this is hidden, but since we are creating the data, we will need to identify this)

# %%
b0 = 0  # y intercept
b1 = -1 # slope for x1
b2 = 1 # slope for x2

# %% [markdown]
# ## Step 3: Create input and output data using the model

# %% [markdown]
# Let's set the number of observations that we will synthesize...

# %%
sample_size = 1000

# %%
x1_mean = 100
x1_stdev = 10
x1 = np.round(np.random.normal(x1_mean, x1_stdev, sample_size),2)

x2_mean = 100
x2_stdev = 10
x2 = np.round(np.random.normal(x2_mean, x2_stdev, sample_size),2)

# %% [markdown]
# Once we have the X values (input), we can generate y values using our 'hidden' model...

# %%
y = b0 + b1*x1 + b2*x2

# %% [markdown]
# But, this is rather boring data to analyze, because the 'hidden' model is not really hidden at all...

# %%
# this is a notebook 'MAGIC' that will allow for creation of interactive plot
# %matplotlib widget 

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(x1, x2, y)

ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('y')
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pip install ipympl
# Out:
# Requirement already satisfied: ipympl in c:\anaconda\lib\site-packages (0.9.2)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\anaconda\lib\site-packages (from ipympl) (7.6.5)
# Requirement already satisfied: ipython-genutils in c:\anaconda\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from ipympl) (1.21.5)
# Requirement already satisfied: pillow in c:\anaconda\lib\site-packages (from ipympl) (9.2.0)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\anaconda\lib\site-packages (from ipympl) (3.5.2)
# Requirement already satisfied: ipython<9 in c:\anaconda\lib\site-packages (from ipympl) (7.31.1)
# Requirement already satisfied: traitlets<6 in c:\anaconda\lib\site-packages (from ipympl) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\anaconda\lib\site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in c:\anaconda\lib\site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: pygments in c:\anaconda\lib\site-packages (from ipython<9->ipympl) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\anaconda\lib\site-packages (from ipython<9->ipympl) (3.0.20)
# Requirement already satisfied: decorator in c:\anaconda\lib\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: pickleshare in c:\anaconda\lib\site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: backcall in c:\anaconda\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from ipython<9->ipympl) (0.4.5)
# Requirement already satisfied: setuptools>=18.5 in c:\anaconda\lib\site-packages (from ipython<9->ipympl) (63.4.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\anaconda\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\anaconda\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\anaconda\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\anaconda\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.15.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\anaconda\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: debugpy>=1.0 in c:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.5)
# Requirement already satisfied: pyzmq>=17 in c:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (23.2.0)
# Requirement already satisfied: psutil in c:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.3.4)
# Requirement already satisfied: tornado>=6.1 in c:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\anaconda\lib\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.16.0)
# Requirement already satisfied: fastjsonschema in c:\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (2.16.2)
# Requirement already satisfied: jupyter_core in c:\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: wcwidth in c:\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\anaconda\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.12)
# Requirement already satisfied: attrs>=17.4.0 in c:\anaconda\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\anaconda\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.0)
# Requirement already satisfied: entrypoints in c:\anaconda\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\anaconda\lib\site-packages (from jupyter_core->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (302)
# Requirement already satisfied: nbconvert>=5 in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.4)
# Requirement already satisfied: jinja2 in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.14.1)
# Requirement already satisfied: argon2-cffi in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.13.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\anaconda\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\anaconda\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\anaconda\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\anaconda\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.13)
# Requirement already satisfied: bleach in c:\anaconda\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: testpath in c:\anaconda\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.6.0)
# Requirement already satisfied: beautifulsoup4 in c:\anaconda\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: defusedxml in c:\anaconda\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\anaconda\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\anaconda\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\anaconda\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\anaconda\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.3.1)
# Requirement already satisfied: webencodings in c:\anaconda\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: pycparser in c:\anaconda\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# %matplotlib inline

# %% [markdown]
# ## Step 4: Add some random noise to 'hide' the model

# %% [markdown]
# Now, let's obscure the model by adding noise to the data by adding errors that are randomly selected from a norma distribution

# %%
e_mean = 0
e_stdev = 180 #here we increase the noise from 10 to 180
e = np.round(np.random.normal(e_mean, e_stdev, sample_size), 2) # round to two decimal places
y = y + e

# %% [markdown]
# ## Step 5: Explore the resulting synthesized data

# %% [markdown]
# Now, let's look at a scatter plot of both the X and y data with the noise added in...

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(x1, x2, y)

ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('y')
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Step 6: Create a pandas data frame from the data

# %% [markdown]
# Since our goal is to generate data that we can analyze with another notebook (for practice), let's save this data to a csv.
#
# First we will create a dataframe with the data we just similated...

# %%
df = pd.DataFrame({'x1': x1, 'x2' : x2, 'target': y})
df
# Out:
#          x1      x2  target
# 0    116.24   98.47   70.34
# 1     93.88   75.67   24.77
# 2     94.72  105.08  -70.30
# 3     89.27   96.76 -102.45
# 4    108.65   84.89 -389.15
# ..      ...     ...     ...
# 995   98.84  101.89 -135.89
# 996   77.23  105.61  -83.70
# 997   99.30   90.78  -35.64
# 998  103.54  106.47 -249.07
# 999   98.13  113.87 -218.45
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## Step 7: Save the data frame contents to a csv

# %% [markdown]
# Lastly, let's save the data we created to a csv file. This saved data will be used to practice finding hidden relationships in data.

# %%
df.to_csv('c02_dataset_2_1st copy.csv', index=False)

# %%
pip install jupyter-summarytools
# Out:
# Requirement already satisfied: jupyter-summarytools in c:\anaconda\lib\site-packages (0.2.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\anaconda\lib\site-packages (from jupyter-summarytools) (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\anaconda\lib\site-packages (from jupyter-summarytools) (1.21.5)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\anaconda\lib\site-packages (from jupyter-summarytools) (3.5.2)
# Requirement already satisfied: ipython>=7.20.0 in c:\anaconda\lib\site-packages (from jupyter-summarytools) (7.31.1)
# Requirement already satisfied: pickleshare in c:\anaconda\lib\site-packages (from ipython>=7.20.0->jupyter-summarytools) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\anaconda\lib\site-packages (from ipython>=7.20.0->jupyter-summarytools) (63.4.1)
# Requirement already satisfied: matplotlib-inline in c:\anaconda\lib\site-packages (from ipython>=7.20.0->jupyter-summarytools) (0.1.6)
# Requirement already satisfied: backcall in c:\anaconda\lib\site-packages (from ipython>=7.20.0->jupyter-summarytools) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\anaconda\lib\site-packages (from ipython>=7.20.0->jupyter-summarytools) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\anaconda\lib\site-packages (from ipython>=7.20.0->jupyter-summarytools) (0.18.1)
# Requirement already satisfied: pygments in c:\anaconda\lib\site-packages (from ipython>=7.20.0->jupyter-summarytools) (2.11.2)
# Requirement already satisfied: decorator in c:\anaconda\lib\site-packages (from ipython>=7.20.0->jupyter-summarytools) (5.1.1)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from ipython>=7.20.0->jupyter-summarytools) (0.4.5)
# Requirement already satisfied: traitlets>=4.2 in c:\anaconda\lib\site-packages (from ipython>=7.20.0->jupyter-summarytools) (5.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->jupyter-summarytools) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->jupyter-summarytools) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->jupyter-summarytools) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->jupyter-summarytools) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->jupyter-summarytools) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->jupyter-summarytools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->jupyter-summarytools) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas>=1.4.0->jupyter-summarytools) (2022.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\anaconda\lib\site-packages (from jedi>=0.16->ipython>=7.20.0->jupyter-summarytools) (0.8.3)
# Requirement already satisfied: wcwidth in c:\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.20.0->jupyter-summarytools) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->jupyter-summarytools) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
