# %% [markdown]
# ICP01 Jupyter Assignment
# Sivagami Bhaskar

# %% [markdown]
# ![Sivagami Photo formal.jpeg](attachment:dfe77c08-35df-4660-aa20-8ab5ea6b874f.jpeg)
# I am Sivagami Bhaskar from India worked majorly on SQL and Teradata doing data governance and regression analysis. Currently, wanted to explore on data science and aiming to be a data scientist.

# %%
print("Hello world!")
# Out:
# Hello world!
